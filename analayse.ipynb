# %%
import pandas as pd
import numpy as np

# %%
file_path = 'US_Accidents.csv'
df = pd.read_csv(file_path, nrows=500000)

# Conversion des dates
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')
df['Year'] = df['Start_Time'].dt.year
df['Hour'] = df['Start_Time'].dt.hour

print(f"Données chargées : {df.shape[0]:,} lignes et {df.shape[1]} colonnes.")
# Out:
# Données chargées : 500,000 lignes et 48 colonnes.

# %%
print(df.head())
# Out:
#     ID   Source  Severity          Start_Time             End_Time  Start_Lat  \
# 0  A-1  Source2         3 2016-02-08 05:46:00  2016-02-08 11:00:00  39.865147
# 1  A-2  Source2         2 2016-02-08 06:07:59  2016-02-08 06:37:59  39.928059
# 2  A-3  Source2         2 2016-02-08 06:49:27  2016-02-08 07:19:27  39.063148
# 3  A-4  Source2         3 2016-02-08 07:23:34  2016-02-08 07:53:34  39.747753
# 4  A-5  Source2         2 2016-02-08 07:39:07  2016-02-08 08:09:07  39.627781
#
#    Start_Lng  End_Lat  End_Lng  Distance(mi)  ...   Stop Traffic_Calming  \
# 0 -84.058723      NaN      NaN          0.01  ...  False           False
# 1 -82.831184      NaN      NaN          0.01  ...  False           False
# 2 -84.032608      NaN      NaN          0.01  ...  False           False
# 3 -84.205582      NaN      NaN          0.01  ...  False           False
# 4 -84.188354      NaN      NaN          0.01  ...  False           False
#
# ...

# %%
print(df.shape)
# Out:
# (500000, 48)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     500000 non-null  object
#  1   Source                 500000 non-null  object
#  2   Severity               500000 non-null  int64
#  3   Start_Time             500000 non-null  datetime64[ns]
#  4   End_Time               500000 non-null  object
#  5   Start_Lat              500000 non-null  float64
#  6   Start_Lng              500000 non-null  float64
#  7   End_Lat                0 non-null       float64
#  8   End_Lng                0 non-null       float64
#  9   Distance(mi)           500000 non-null  float64
#  10  Description            500000 non-null  object
#  11  Street                 500000 non-null  object
#  12  City                   499978 non-null  object
#  13  County                 500000 non-null  object
# ...

# %%
# pour calculer les valeurs manquantes de la colonne Sunrise_Sunset et wind_direction
import pandas as pd
df=pd.read_csv('US_Accidents.csv')
df['Sunrise_Sunset'].isna().sum()
df['Wind_Direction'].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 # pour calculer les valeurs manquantes de la colonne Sunrise_Sunset et wind_direction
#       2 import pandas as pd
# ----> 3 df=pd.read_csv('US_Accidents.csv')
#       4 df['Sunrise_Sunset'].isna().sum()
#       5 df['Wind_Direction'].isna().sum()
#
# ...

# %%
# verifier la forme des dates
df['Start_Time'].head(500000)
# Out:
# 0        2016-02-08 05:46:00
# 1        2016-02-08 06:07:59
# 2        2016-02-08 06:49:27
# 3        2016-02-08 07:23:34
# 4        2016-02-08 07:39:07
#                  ...
# 499995   2017-07-21 09:21:24
# 499996   2017-07-21 09:48:10
# 499997   2017-07-21 11:02:10
# 499998   2017-07-21 11:09:58
# 499999   2017-07-21 11:42:56
# Name: Start_Time, Length: 500000, dtype: datetime64[ns]

# %%
# pour verifier la forme des dates de tous les colonnes de type datetime
date_columns = df.select_dtypes(include=['datetime64[ns]']).columns
for col in date_columns:
    print(f"Colonne: {col}")
    print(df[col].head())
# Out:
# Colonne: Start_Time
# 0   2016-02-08 05:46:00
# 1   2016-02-08 06:07:59
# 2   2016-02-08 06:49:27
# 3   2016-02-08 07:23:34
# 4   2016-02-08 07:39:07
# Name: Start_Time, dtype: datetime64[ns]

# %%
# pour changer le type des colonne start_time, end_time, weather_timestamp to datetime
date_cols = ['Start_Time', 'End_Time', 'Weather_Timestamp']
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')
    print(f"Colonne {col} convertie en datetime.")
    print(df[col].head())
# Out:
# Colonne Start_Time convertie en datetime.
# 0   2016-02-08 05:46:00
# 1   2016-02-08 06:07:59
# 2   2016-02-08 06:49:27
# 3   2016-02-08 07:23:34
# 4   2016-02-08 07:39:07
# Name: Start_Time, dtype: datetime64[ns]
# Colonne End_Time convertie en datetime.
# 0   2016-02-08 11:00:00
# 1   2016-02-08 06:37:59
# 2   2016-02-08 07:19:27
# 3   2016-02-08 07:53:34
# 4   2016-02-08 08:09:07
# Name: End_Time, dtype: datetime64[ns]
# Colonne Weather_Timestamp convertie en datetime.
# 0   2016-02-08 05:58:00
# 1   2016-02-08 05:51:00
# 2   2016-02-08 06:56:00
# 3   2016-02-08 07:38:00
# 4   2016-02-08 07:53:00
# Name: Weather_Timestamp, dtype: datetime64[ns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     500000 non-null  object
#  1   Source                 500000 non-null  object
#  2   Severity               500000 non-null  int64
#  3   Start_Time             500000 non-null  datetime64[ns]
#  4   End_Time               500000 non-null  datetime64[ns]
#  5   Start_Lat              500000 non-null  float64
#  6   Start_Lng              500000 non-null  float64
#  7   End_Lat                0 non-null       float64
#  8   End_Lng                0 non-null       float64
#  9   Distance(mi)           500000 non-null  float64
#  10  Description            500000 non-null  object
#  11  Street                 500000 non-null  object
#  12  City                   499978 non-null  object
#  13  County                 500000 non-null  object
# ...

# %%
#pour avoir le nombre des ligne dans la data complete
import pandas as pd
df_full= pd.read_csv('US_Accidents.csv')
